# %% [markdown]
# # Method comparison
#
# Compare methods on Q1’s frozen missense validation set. Run this notebook once to enable automatic refresh, then reload it after source results change.

# %%
from notebooks.src import comparison
comparison.show()
# Out:
# **1,342 missense validation variants · ClinVar labels**
# <table class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Method</th>
#       <th>Notebook</th>
#       <th>Scored / validation</th>
#       <th>AUROC [95% CI]</th>
#       <th>Average precision [95% CI]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Evo2 + logistic regression</td>
#       <td><a href="notebooks/Q2-evo2-classifier.ipynb">Q2</a></td>
#       <td>1,342 / 1,342</td>
#       <td>0.861 [0.834, 0.885]</td>
#       <td>0.775 [0.719, 0.822]</td>
#     </tr>
#     <tr>
#       <td>Evo2 zero-shot</td>
#       <td><a href="notebooks/Q2-evo2-classifier.ipynb">Q2</a></td>
#       <td>1,342 / 1,342</td>
#       <td>0.866 [0.840, 0.890]</td>
#       <td>0.769 [0.713, 0.817]</td>
#     </tr>
#     <tr>
#       <td>Sequence + logistic regression</td>
#       <td><a href="notebooks/Q2-evo2-classifier.ipynb">Q2</a></td>
#       <td>1,342 / 1,342</td>
# ...
